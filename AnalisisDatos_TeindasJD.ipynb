# %% [markdown]
# ### Importación de datos

# %% [markdown]
# Let's start by examining the first few rows of the dataframe to get a glimpse of the data.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
display(tienda.head())
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
display(tienda.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
# None

# %%
display(tienda.describe())
# Out:
#              Precio  Costo de envío  Calificación  Cantidad de cuotas  \
# count  2.359000e+03     2359.000000   2359.000000         2359.000000
# mean   4.878679e+05    26018.609580      3.976685            2.943196
# std    6.146868e+05    32860.001783      1.415370            2.819897
# min    7.600000e+03        0.000000      1.000000            1.000000
# 25%    5.575000e+04     3100.000000      3.000000            1.000000
# 50%    2.353000e+05    12400.000000      5.000000            1.000000
# 75%    6.781000e+05    36000.000000      5.000000            4.000000
# max    2.977000e+06   160800.000000      5.000000           24.000000
#
#                lat          lon
# count  2359.000000  2359.000000
# mean      5.365283   -74.789417
# std       2.287445     1.217827
# min      -4.215280   -77.281110
# 25%       4.609710   -75.563590
# 50%       4.609710   -74.199040
# 75%       6.251840   -74.081750
# max      11.544440   -67.923900

# %%
total_revenue_tienda1 = tienda['Precio'].sum()
total_revenue_tienda2 = tienda2['Precio'].sum()
total_revenue_tienda3 = tienda3['Precio'].sum()
total_revenue_tienda4 = tienda4['Precio'].sum()

print(f"Total revenue for Tienda 1: {total_revenue_tienda1:,.2f}")
print(f"Total revenue for Tienda 2: {total_revenue_tienda2:,.2f}")
print(f"Total revenue for Tienda 3: {total_revenue_tienda3:,.2f}")
print(f"Total revenue for Tienda 4: {total_revenue_tienda4:,.2f}")
# Out:
# Total revenue for Tienda 1: 1,150,880,400.00
# Total revenue for Tienda 2: 1,116,343,500.00
# Total revenue for Tienda 3: 1,098,019,600.00
# Total revenue for Tienda 4: 1,038,375,700.00

# %% [markdown]
# # 2. Ventas por categoría

# %%
category_sales_tienda1 = tienda['Categoría del Producto'].value_counts()
category_sales_tienda2 = tienda2['Categoría del Producto'].value_counts()
category_sales_tienda3 = tienda3['Categoría del Producto'].value_counts()
category_sales_tienda4 = tienda4['Categoría del Producto'].value_counts()

print("Category wise sales for Tienda 1:")
display(category_sales_tienda1)

print("\nCategory wise sales for Tienda 2:")
display(category_sales_tienda2)

print("\nCategory wise sales for Tienda 3:")
display(category_sales_tienda3)

print("\nCategory wise sales for Tienda 4:")
display(category_sales_tienda4)
# Out:
# Category wise sales for Tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
# Category wise sales for Tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
# Category wise sales for Tienda 3:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
average_rating_tienda1 = tienda['Calificación'].mean()
average_rating_tienda2 = tienda2['Calificación'].mean()
average_rating_tienda3 = tienda3['Calificación'].mean()
average_rating_tienda4 = tienda4['Calificación'].mean()

print(f"Average rating for Tienda 1: {average_rating_tienda1:.2f}")
print(f"Average rating for Tienda 2: {average_rating_tienda2:.2f}")
print(f"Average rating for Tienda 3: {average_rating_tienda3:.2f}")
print(f"Average rating for Tienda 4: {average_rating_tienda4:.2f}")
# Out:
# Average rating for Tienda 1: 3.98
# Average rating for Tienda 2: 4.04
# Average rating for Tienda 3: 4.05
# Average rating for Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Most and least sold products for Tienda 1
product_sales_tienda1 = tienda['Producto'].value_counts()
print("Most sold products for Tienda 1:")
display(product_sales_tienda1.head(10))
print("\nLeast sold products for Tienda 1:")
display(product_sales_tienda1.tail(10))

# Most and least sold products for Tienda 2
product_sales_tienda2 = tienda2['Producto'].value_counts()
print("\nMost sold products for Tienda 2:")
display(product_sales_tienda2.head(10))
print("\nLeast sold products for Tienda 2:")
display(product_sales_tienda2.tail(10))

# Most and least sold products for Tienda 3
product_sales_tienda3 = tienda3['Producto'].value_counts()
print("\nMost sold products for Tienda 3:")
display(product_sales_tienda3.head(10))
print("\nLeast sold products for Tienda 3:")
display(product_sales_tienda3.tail(10))

# Most and least sold products for Tienda 4
product_sales_tienda4 = tienda4['Producto'].value_counts()
print("\nMost sold products for Tienda 4:")
display(product_sales_tienda4.head(10))
print("\nLeast sold products for Tienda 4:")
display(product_sales_tienda4.tail(10))
# Out:
# Most sold products for Tienda 1:
# Producto
# Microondas                 60
# TV LED UHD 4K              60
# Armario                    60
# Secadora de ropa           58
# Mesa de noche              56
# Bloques de construcción    56
# Balón de baloncesto        55
# Bicicleta                  54
# Vaso térmico               54
# Refrigerador               54
# Name: count, dtype: int64
# Least sold products for Tienda 1:
# Producto
# Muñeca bebé                    40
# Mesa de comedor                40
# Dinosaurio Rex                 40
# Cuerda para saltar             40
# Mochila                        39
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64
# Most sold products for Tienda 2:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
average_shipping_tienda1 = tienda['Costo de envío'].mean()
average_shipping_tienda2 = tienda2['Costo de envío'].mean()
average_shipping_tienda3 = tienda3['Costo de envío'].mean()
average_shipping_tienda4 = tienda4['Costo de envío'].mean()

print(f"Average shipping cost for Tienda 1: {average_shipping_tienda1:,.2f}")
print(f"Average shipping cost for Tienda 2: {average_shipping_tienda2:,.2f}")
print(f"Average shipping cost for Tienda 3: {average_shipping_tienda3:,.2f}")
print(f"Average shipping cost for Tienda 4: {average_shipping_tienda4:,.2f}")
# Out:
# Average shipping cost for Tienda 1: 26,018.61
# Average shipping cost for Tienda 2: 25,216.24
# Average shipping cost for Tienda 3: 24,805.68
# Average shipping cost for Tienda 4: 23,459.46

# %% [markdown]
# Now, let's check the data types and the number of non-null values in each column. This will help us understand the structure and identify potential missing data.

# %%
display(tienda.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
# None

# %% [markdown]
# Finally, let's look at some descriptive statistics for the numerical columns. This will give us an idea of the distribution and range of values in the dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bar plot for total revenue per store
revenue_data = {'Store': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
                'Total Revenue': [total_revenue_tienda1, total_revenue_tienda2, total_revenue_tienda3, total_revenue_tienda4]}
revenue_df = pd.DataFrame(revenue_data)

plt.figure(figsize=(10, 6))
sns.barplot(x='Store', y='Total Revenue', data=revenue_df)
plt.title('Total Revenue per Store')
plt.ylabel('Total Revenue')
plt.xlabel('Store')
plt.show()

# Bar plot for category wise sales for Tienda 1 (as an example)
plt.figure(figsize=(12, 7))
sns.barplot(x=category_sales_tienda1.index, y=category_sales_tienda1.values)
plt.title('Category Wise Sales for Tienda 1')
plt.xlabel('Product Category')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Histogram of ratings for Tienda 1 (as an example)
plt.figure(figsize=(10, 6))
sns.histplot(tienda['Calificación'], bins=5, kde=True)
plt.title('Distribution of Ratings for Tienda 1')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Informe Final: Análisis de Tiendas para la Decisión de Venta
#
# **Introducción:**
#
# El propósito de este informe es analizar los datos de cuatro tiendas para determinar cuál sería la más adecuada para que el Sr. Juan venda sus productos, basándonos en métricas clave como ingresos, ventas por categoría, calificaciones de clientes, productos más y menos vendidos, y costos de envío promedio. El objetivo es proporcionar una recomendación justificada y respaldada por los datos.
#
# **Desarrollo:**
#
# Hemos analizado los datos de las tiendas 1, 2, 3 y 4. A continuación, se presentan los hallazgos más relevantes:
#
# **1. Ingresos Totales:**
#
# Los ingresos totales de cada tienda son los siguientes:
#
# *   Tienda 1: $1,150,880,400.00
# *   Tienda 2: $1,116,343,500.00
# *   Tienda 3: $1,098,019,600.00
# *   Tienda 4: $1,038,375,700.00
#
# Como se puede observar en el gráfico de barras de "Total Revenue per Store", la Tienda 1 presenta los ingresos totales más altos, seguida de la Tienda 2, Tienda 3 y Tienda 4.
#
# **2. Ventas por Categoría:**
#
# El análisis de ventas por categoría mostró la distribución de productos vendidos en cada tienda. Si bien hay variaciones, categorías como "Muebles", "Electrónicos" y "Juguetes" tienden a tener un alto volumen de ventas en todas las tiendas. Por ejemplo, el gráfico "Category Wise Sales for Tienda 1" ilustra esta distribución para la Tienda 1, mostrando la popularidad de estas categorías.
#
# **3. Calificaciones Promedio de Clientes:**
#
# Las calificaciones promedio de los clientes son un indicador de la satisfacción con los productos y servicios de cada tienda:
#
# *   Tienda 1: 3.98
# *   Tienda 2: 4.04
# *   Tienda 3: 4.05
# *   Tienda 4: 4.00
#
# Las Tiendas 2 y 3 tienen las calificaciones promedio más altas, lo que sugiere una mayor satisfacción del cliente en estas tiendas. La Tienda 1 y Tienda 4 tienen calificaciones ligeramente inferiores pero aún así buenas. El histograma de "Distribution of Ratings for Tienda 1" muestra la distribución de calificaciones, indicando que la mayoría de los clientes tienden a dar calificaciones altas.
#
# **4. Productos Más y Menos Vendidos:**
#
# Identificar los productos más y menos vendidos en cada tienda nos da una idea de las preferencias de los clientes y el rendimiento de los productos individuales. Los resultados varían entre tiendas, lo que sugiere que el público objetivo y las estrategias de inventario pueden ser diferentes. Al analizar las listas de productos más y menos vendidos, el Sr. Juan puede evaluar si sus productos se alinean con las tendencias de ventas de cada tienda.
#
# **5. Costo de Envío Promedio:**
#
# El costo de envío promedio para cada tienda es el siguiente:
#
# *   Tienda 1: $26,018.61
# *   Tienda 2: $25,216.24
# *   Tienda 3: $24,805.68
# *   Tienda 4: $23,459.46
#
# La Tienda 4 tiene el costo de envío promedio más bajo, mientras que la Tienda 1 tiene el más alto. Esto podría influir en la rentabilidad para el Sr. Juan, dependiendo de la estructura de costos de sus productos y las políticas de envío de cada tienda.
#
# **Conclusión y Recomendación:**
#
# Considerando todos los factores analizados, la **Tienda 1** parece ser la opción más prometedora para que el Sr. Juan venda sus productos. Aunque sus costos de envío promedio son los más altos, sus ingresos totales son significativamente mayores que los de las otras tiendas. Esto sugiere un mayor volumen de ventas general, lo que podría compensar los costos de envío más altos.
#
# Si bien las Tiendas 2 y 3 tienen calificaciones de clientes ligeramente más altas, la diferencia en los ingresos totales es considerable. La Tienda 4 tiene los ingresos más bajos y el costo de envío promedio más bajo, lo que podría ser atractivo en términos de costos operativos, pero el menor volumen de ventas podría limitar el alcance del Sr. Juan.
#
# Por lo tanto, la Tienda 1, a pesar de su costo de envío promedio más alto, ofrece el mayor potencial de ingresos debido a su alto volumen de ventas. Se recomienda al Sr. Juan que venda sus productos en la Tienda 1.
#
# Sin embargo, es importante que el Sr. Juan evalúe cómo sus productos específicos se alinean con las categorías y productos más vendidos en la Tienda 1 para maximizar su éxito.
